# %% [markdown]
# # Invariant Coordinate Selection (ICS) Python implementation
#
# Ready to dive into **ICS** in Python? This tutorial will guide you through using `ICSpyLab`, the package implementing ICS, with practical examples to help you get started.
#
# The tutorial references examples available in the package [documentation](https://icspylab.readthedocs.io/en/latest/index.html).
#
# You can also explore the [Github Repository](https://github.com/cbecquart/ICSpyLab), where you’ll find the source code and contribution guidelines.

# %%
# !python --version
# Out:
# Python 3.12.13

# %% [markdown]
# To install the package, use pip:

# %%
# !pip install icspylab
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 741.8 kB/s eta 0:00:00
# ...

# %% [markdown]
# ## Getting Started
#
#
#
# 1.   [Quick Start](https://icspylab.readthedocs.io/en/latest/getting_started/quickstart.html)
# 2.   [Custom Scatter](https://icspylab.readthedocs.io/en/latest/getting_started/custom_scatter.html)
# 3.   [Custom Component Selection](https://icspylab.readthedocs.io/en/latest/getting_started/custom_compselect.html)
#
#
# ## Application
#
#
#
# 1.   [RANDU example](https://icspylab.readthedocs.io/en/latest/examples/randu.html)
# 2.   [Circular structure example](https://icspylab.readthedocs.io/en/latest/examples/circle.html)
# 3.   [Outlier detection](https://icspylab.readthedocs.io/en/latest/examples/outliers.html)
